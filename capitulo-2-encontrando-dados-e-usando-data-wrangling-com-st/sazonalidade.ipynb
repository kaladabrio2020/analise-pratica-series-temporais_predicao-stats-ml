# %%
library(zoo)
library(data.table)
library(forecast)
data("AirPassengers")

# %%
passer = AirPassengers

# %%
head(passer, 10)
# Out:
#      Jan Feb Mar Apr May Jun Jul Aug Sep Oct
# 1949 112 118 132 129 121 135 148 148 136 119

# %%
par(bg = 'white')
options(repr.plot.width = 15, repr.plot.height = 10)

plot(stl(passer, s.window = 'periodic'))
# Out:
# plot without title
