# %%
library(forecast)
library(zoo)
library(data.table)
# Out:
# Anexando pacote: 'data.table'
#
#
# Os seguintes objetos são mascarados por 'package:zoo':
#
#     yearmon, yearqtr

# %%
data = fread('dataset-example\\student_data.csv')

# %%
head(data, 4)
# Out:
#   school sex age address famsize Pstatus Medu Fedu Mjob    Fjob     ⋯ famrel
# 1 GP     F   18  U       GT3     A       4    4    at_home teacher  ⋯ 4
# 2 GP     F   17  U       GT3     T       1    1    at_home other    ⋯ 5
# 3 GP     F   15  U       LE3     T       1    1    at_home other    ⋯ 4
# 4 GP     F   15  U       GT3     T       4    2    health  services ⋯ 3
#   freetime goout Dalc Walc health absences G1 G2 G3
# 1 3        4     1    1    3       6        5  6  6
# 2 3        3     1    1    3       4        5  5  6
# 3 3        2     2    3    3      10        7  8 10
# 4 2        2     1    1    5       2       15 14 15

# %%
data[, mean(age), by=sex]
# Out:
#   sex V1
# 1 F   16.73077
# 2 M   16.65775

# %%
data[, nomes:= paste(as.character(age), Fjob)]
data
# Out:
#     school sex age address famsize Pstatus Medu Fedu Mjob     Fjob     ⋯
# 1   GP     F   18  U       GT3     A       4    4    at_home  teacher  ⋯
# 2   GP     F   17  U       GT3     T       1    1    at_home  other    ⋯
# 3   GP     F   15  U       LE3     T       1    1    at_home  other    ⋯
# 4   GP     F   15  U       GT3     T       4    2    health   services ⋯
# 5   GP     F   16  U       GT3     T       3    3    other    other    ⋯
# 6   GP     M   16  U       LE3     T       4    3    services other    ⋯
# 7   GP     M   16  U       LE3     T       2    2    other    other    ⋯
# 8   GP     F   17  U       GT3     A       4    4    other    teacher  ⋯
# 9   GP     M   15  U       LE3     A       3    2    services other    ⋯
# 10  GP     M   15  U       GT3     T       3    4    other    other    ⋯
# 11  GP     F   15  U       GT3     T       4    4    teacher  health   ⋯
# 12  GP     F   15  U       GT3     T       2    1    services other    ⋯
# ...
